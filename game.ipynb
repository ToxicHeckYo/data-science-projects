# %% [markdown]
# # Игра угадай число

# %%
from game import score_game
from game import find_predict

# %% [markdown]
# ## Угадываем число

# %%
score_game(find_predict, 1, 200)
# Out:
# Ваш алгоритм угадывает число в среднем за: 6 попыток
# 6
