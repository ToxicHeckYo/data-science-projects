# %% [markdown]
# # Игра угадай число

# %%
from game import score_game
from game import find_predict

# %% [markdown]
# ## Угадываем число

# %%
score_game(find_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 5 попыток
# 5
